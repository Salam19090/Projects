# %%
import pandas as pd
from scipy.stats import ttest_ind

# %%
df = pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/018/746/original/loan.csv?1666170299")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.columns.to_list()
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
gum = df[(df['Education'] == 'Graduate') & (df['Married'] == 'No')]['ApplicantIncome']
d1 = len(gum)
d1
d2 = len(df)
# Out:
# 309

# %%
p = pd.read_csv('https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/715/original/sales_dataset.csv?1651726697')
p.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
p.describe(include = 'all')
# Out:
#         Invoice StockCode                         Description      Quantity  \
# count   1067371   1067371                             1062989  1.067371e+06
# unique    53628      5305                                5698           NaN
# top      537434    85123A  WHITE HANGING HEART T-LIGHT HOLDER           NaN
# freq       1350      5829                                5918           NaN
# mean        NaN       NaN                                 NaN  9.938898e+00
# std         NaN       NaN                                 NaN  1.727058e+02
# min         NaN       NaN                                 NaN -8.099500e+04
# 25%         NaN       NaN                                 NaN  1.000000e+00
# 50%         NaN       NaN                                 NaN  3.000000e+00
# 75%         NaN       NaN                                 NaN  1.000000e+01
# max         NaN       NaN                                 NaN  8.099500e+04
#
# ...

# %%
p.groupby('Description').count()
# Out:
#                                      Invoice  StockCode  Quantity  \
# Description
#   DOORMAT UNION JACK GUNS AND ROSES       62         62        62
#  3 STRIPEY MICE FELTCRAFT                134        134       134
#  4 PURPLE FLOCK DINNER CANDLES            62         62        62
#  50'S CHRISTMAS GIFT BAG LARGE           130        130       130
#  ANIMAL STICKERS                          12         12        12
# ...                                      ...        ...       ...
# wrongly marked carton 22804                1          1         1
# wrongly marked. 23343 in box               1          1         1
# wrongly sold (22719) barcode               1          1         1
# wrongly sold as sets                       1          1         1
# wrongly sold sets                          1          1         1
#
#                                      InvoiceDate  Price  Customer ID  Country
# Description
# ...

# %%
path = r"C:\Users\SHAHNOOR ALAM\Downloads\fortune1000.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
# Out:
# Empty DataFrame
# Columns: [Rank, Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
data.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
data['Sector'].nunique()
# Out:
# 21

# %%
data.groupby('Sector')['Revenue'].max()
# Out:
# Sector
# Aerospace & Defense              96114
# Apparel                          30601
# Business Services                19330
# Chemicals                        48778
# Energy                          246204
# Engineering & Construction       18114
# Financials                      210821
# Food and Drug Stores            153290
# Food, Beverages & Tobacco        67702
# Health Care                     181241
# Hotels, Resturants & Leisure     25413
# Household Products               78756
# Industrials                     140389
# Materials                        22534
# Media                            52465
# Motor Vehicles & Parts          152356
# Retailing                       482130
# Technology                      233715
# Telecommunications              146801
# Transportation                   58363
# Wholesalers                      48681
# Name: Revenue, dtype: int64

# %%
data.groupby('Sector').aggregate({'Revenue': 'max', 'Employees': ('min', 'mean')})
# Out:
#                              Revenue Employees
#                                  max       min          mean
# Sector
# Aerospace & Defense            96114      6955  48402.850000
# Apparel                        30601      5978  23093.133333
# Business Services              19330      2400  26687.254902
# Chemicals                      48778      1979  15455.033333
# Energy                        246204       480   9745.303279
# Engineering & Construction     18114      1036  15642.615385
# Financials                    210821       187  24172.287770
# Food and Drug Stores          153290      1616  93026.533333
# Food, Beverages & Tobacco      67702      1857  28177.488372
# Health Care                   181241      2924  35710.520000
# Hotels, Resturants & Leisure   25413      8500  99369.800000
# Household Products             78756      4406  23072.785714
# Industrials                   140389      4104  33591.934783
# ...

# %%
#Find the top 3 Revenue for each sectors

# %%
data.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
data.groupby('Sector')['Revenue'].sum().sort_values(ascending = False).values[0:3]
# Out:
# array([2217159, 1614707, 1517809], dtype=int64)

# %%
top_revenues = data.groupby('Sector').apply(lambda x: x.nlargest(3, 'Revenue'))
top_revenues = top_revenues.reset_index(drop=True)
top_revenues
# Out:
#     Rank                  Company               Sector  \
# 0     24                   Boeing  Aerospace & Defense
# 1     45      United Technologies  Aerospace & Defense
# 2     60          Lockheed Martin  Aerospace & Defense
# 3     91                     Nike              Apparel
# 4    231                       VF              Apparel
# ..   ...                      ...                  ...
# 58    58                    FedEx       Transportation
# 59    67  American Airlines Group       Transportation
# 60    57                    Sysco          Wholesalers
# 61    64             Ingram Micro          Wholesalers
# 62    92      World Fuel Services          Wholesalers
#
#                                          Industry        Location  Revenue  \
# 0                           Aerospace and Defense     Chicago, IL    96114
# 1                           Aerospace and Defense  Farmington, CT    61047
# 2                           Aerospace and Defense    Bethesda, MD    46132
# ...

# %%
newdf = data.groupby(['Sector'])['Industry','Location','Revenue'].apply(lambda x: x.sort_values(by='Revenue',ascending=False))
newdf.groupby('Sector').head(3)
# Out:
# C:\Users\SHAHNOOR ALAM\AppData\Local\Temp\ipykernel_15928\631740034.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   newdf = data.groupby(['Sector'])['Industry','Location','Revenue'].apply(lambda x: x.sort_values(by='Revenue',ascending=False))
#                                                               Industry  \
# Sector
# Aerospace & Defense 23                           Aerospace and Defense
#                     44                           Aerospace and Defense
#                     59                           Aerospace and Defense
# Apparel             90                                         Apparel
#                     230                                        Apparel
# ...                                                                ...
# Transportation      57             Mail, Package, and Freight Delivery
# ...
