# %% [markdown]
#   # BUSINESS CASE - NETFLIX

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
data = pd.read_csv(url)
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Getting some basic info about the dataset.

# %% [markdown]
# # Head

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Tail

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# # Shape

# %%
data.shape
# Out:
# (8807, 12)

# %% [markdown]
# # Size

# %%
data.size
# Out:
# 105684

# %% [markdown]
# # Info

# %%
data.info
# Out:
# <bound method DataFrame.info of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %% [markdown]
# # Data Description

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# # Columns

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Data Types

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # Duplicate records

# %%
data[data.duplicated()]  # no duplicate record found.
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# # Null values present in columns

# %%
data.isnull() # TRUE means null value available.
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()  # DIRECTOR column has most null values.
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.isnull().sum().sum()   # Total numbers of null values in the dataset.
# Out:
# 4307

# %%
data[data.duration.isnull()] # Number of null vlause in duration column.
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
data.head(1)
# Out:
#   show_id   type                 title         director cast        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added  release_year rating duration      listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min  Documentaries
#
#                                          description
# 0  As her father nears the end of his life, filmm...

# %% [markdown]
# # Converting data types from object to date time .

# %% [markdown]
# Updating data type of date_added to date time data type.

# %%
data['date_added'] = pd.to_datetime(data['date_added'])
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %% [markdown]
# # Handling missing data -

# %% [markdown]
# Following columns does not require fills :-

# %% [markdown]
#  *  show_id
#  *  type
#  *  title
#  *  release_year
#  *  listed_in
#  *  description

# %% [markdown]
# Following columns require fills :-

# %% [markdown]
#  * director
#  * cast
#  * country
#  * rating
#  * duration

# %% [markdown]
# To fill the data in missing place will take mode of available values except duration column as missing values of duration column
# misplaced in rating column.
#  * Duration data input error.

# %%
data[data.duration.isnull()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %% [markdown]
# As we can see that in above code only director "Louis C.K" has missing values in rating columns. So first need to verify how many rows under director "Louis C.K" .

# %%
data[data.director == 'Louis C.K.'] # This shows total number of rows containing Louis C.K.
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
data.loc[data['director'] == 'Louis C.K.', 'duration'] = data['rating']
data[data.director == 'Louis C.K.']
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min   74 min
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min   84 min
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min   66 min
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Taking mode of columns which have missing values to fill.

# %%
r = data['rating'].mode()
c = data['cast'].mode()
d = data['director'].mode()
c1 = data['country'].mode()
d1 = data['date_added'].mode()
print(d)
print(d1)
print(c)
print(d)
print(c1)
# Out:
# 0    Rajiv Chilaka
# Name: director, dtype: object
# 0   2020-01-01
# Name: date_added, dtype: datetime64[ns]
# 0    David Attenborough
# Name: cast, dtype: object
# 0    Rajiv Chilaka
# Name: director, dtype: object
# 0    United States
# Name: country, dtype: object

# %%
df = data.fillna({'rating' : 'TV-MA' , 'cast' : 'David Attenborough', 
             'director' : 'Rajiv Chilaka', 'country' : 'United States', 'date_added' : '2020-01-01'})
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water    Rajiv Chilaka
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4      s5  TV Show           Kota Factory    Rajiv Chilaka
#
#                                                 cast        country  \
# 0                                 David Attenborough  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                 David Attenborough  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# Types of shows watched in Netflix :-

# %%
data.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(x = 'type', data = data)
plt.title("Movies VS TV shows")
plt.show()

# %% [markdown]
# Netflix has more movis than TV shows.

# %% [markdown]
# Country analysis

# %%
data["country"].value_counts().head(10)
# Out:
# United States     3649
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: country, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'country' , order = data['country'].value_counts().index[0:10], data = data)
plt.title("Country wise content list")
plt.show()

# %% [markdown]
# Type of content based on country

# %%
movie_countries = data[data['type'] == 'Movie']
tv_show_countries = data[data['type'] == 'TV Show']

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'country' , order = data['country'].value_counts().index[0:10], data = movie_countries)
plt.title('Top 10 countries producing Movie on netflix')


plt.figure(figsize = (12,6))
sns.countplot(x = 'country' , order = data['country'].value_counts().index[0:10], data = tv_show_countries)
plt.title('Top 10 countries producing TV_show on netflix')
plt.show()

# %% [markdown]
# # Boxplot of type by release year

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = data, x='type', y='release_year')
plt.title('Boxplot of release year by Type')
plt.show()

# %% [markdown]
# Analysis of ratings given in Netflix

# %%
data.rating.value_counts()
# Out:
# TV-MA       3211
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
plt.figure(figsize = (9,6))
sns.countplot(x = "rating", order = data['rating'].value_counts().index[0:10], data=data)
plt.title('Rating of shows Vs count in Netflix')
plt.show()

# %% [markdown]
# Most of the shows has TV-MA and TV-14 rating in Netflix.

# %%
data.release_year.value_counts()[:20]
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# 2007      88
# 2005      80
# 2004      64
# 2003      61
# 2002      51
# Name: release_year, dtype: int64

# %%
plt.figure(figsize = (11,6))
sns.countplot(x = 'release_year', order = data['release_year'].value_counts().index[0:20], data=data)
plt.title("Content release in year")
plt.show()

# %% [markdown]
# # Heatmap of the given dataset

# %%
counts = data.groupby(['type', 'listed_in']).size().unstack()
counts = counts.div(counts.sum(axis=1), axis=0)
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(counts, cmap='Blues', annot=True, fmt='.9%', ax=ax)
plt.title('Percentage of Movies and TV Shows in Each Genre')
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.pairplot(data.select_dtypes(include=['float64', 'int64']))
plt.title('Pairplot of Netflix Data')
plt.show()

# %% [markdown]
# # INSIGHT

# %% [markdown]
# 1. Netflix has more movies than TV shows.
# 2. Most number of movies and TV shows are produced by United states followed by India who has produced the second most number of movies on Netflix.
# 3. Most of the content on Netflix (Movies and TV shows) is for Mature Audiences.
# 4. 2018 is the year in which Netflix released alot more content as compare to other years.
# 5. International movies and Dramas are the most popular on Netflix.

# %% [markdown]
# # RECOMMENDATIONS

# %% [markdown]
# 1. Netflix needs to have different stratergy in terms of producing content for western countries and south asian countries.
# 2. Drama is the most popular genre worldwide.So, Netflix can always rely on Drama type content for increasing market share and its growth in different countries.
# 3. There was slight drop in content recently due to covid but company was performing well.
# 4. Always try to release content during festive seasons or holidays like in the month of july and december with respect to location.
# 5. Following are the top 5 experienced directors in the field of movies: Jan Suter Raúl Campos Marcus Raboy Rajiv Chilaka Richard Bailey
